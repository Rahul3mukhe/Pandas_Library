# %%
import pandas as pd
var = pd.DataFrame({'a':[1,2,3,4],'b':[5,6,7,8]})
var
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
var["c"] = var["a"] + var["b"]
var
# Out:
#    a  b   c
# 0  1  5   6
# 1  2  6   8
# 2  3  7  10
# 3  4  8  12

# %%
var["c"] = var["a"] * var["b"]
var
# Out:
#    a  b   c
# 0  1  5   5
# 1  2  6  12
# 2  3  7  21
# 3  4  8  32

# %%
var["c"] = var["a"] / var["b"]
var
# Out:
#    a  b         c
# 0  1  5  0.200000
# 1  2  6  0.333333
# 2  3  7  0.428571
# 3  4  8  0.500000

# %%
var1 = pd.DataFrame({"a":[10,20,30,40],"b":[15,30,45,60]})
var1
# Out:
#     a   b
# 0  10  15
# 1  20  30
# 2  30  45
# 3  40  60

# %%
var1["python"] = var1["a"]<=20
var1["python_1"] = var1["b"]>=16
var1
# Out:
#     a   b  python  python_1
# 0  10  15    True     False
# 1  20  30    True      True
# 2  30  45   False      True
# 3  40  60   False      True
