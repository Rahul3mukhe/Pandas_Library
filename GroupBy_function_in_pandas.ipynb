# %%
import pandas as pd
var = pd.DataFrame({ " Name " : ["a","b","c","d","d","a","c","b"],
                          "s_1" : [12,13,14,12,13,16,12,13],
                          "s_2" : [23,24,23,26,24,27,25,28]})
print(var)
# Out:
#    Name   s_1  s_2
# 0      a   12   23
# 1      b   13   24
# 2      c   14   23
# 3      d   12   26
# 4      d   13   24
# 5      a   16   27
# 6      c   12   25
# 7      b   13   28

# %%
var_new = var.groupby(" Name ")
var_new

# %%
for x,y in var_new:
  print(x)
  print(y)
  print()
# Out:
# a
#    Name   s_1  s_2
# 0      a   12   23
# 5      a   16   27
#
# b
#    Name   s_1  s_2
# 1      b   13   24
# 7      b   13   28
#
# c
#    Name   s_1  s_2
# 2      c   14   23
# 6      c   12   25
#
# d
#    Name   s_1  s_2
# 3      d   12   26
# 4      d   13   24

# %%
var_new.get_group("a")
# Out:
#    Name   s_1  s_2
# 0      a   12   23
# 5      a   16   27

# %%
var_new.min()
# Out:
#         s_1  s_2
#  Name
# a        12   23
# b        13   24
# c        12   23
# d        12   24

# %%
var_new.max()
# Out:
#         s_1  s_2
#  Name
# a        16   27
# b        13   28
# c        14   25
# d        13   26

# %%
li = list(var_new)
li
# Out:
# [('a',
#      Name   s_1  s_2
#   0      a   12   23
#   5      a   16   27),
#  ('b',
#      Name   s_1  s_2
#   1      b   13   24
#   7      b   13   28),
#  ('c',
#      Name   s_1  s_2
#   2      c   14   23
#   6      c   12   25),
#  ('d',
#      Name   s_1  s_2
#   3      d   12   26
#   4      d   13   24)]
